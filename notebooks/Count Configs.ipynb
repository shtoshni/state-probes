# %%
colors = ["a", "b", "c", "d", "e", "f"]
from itertools import product

# %%
from collections import Counter

counter = Counter()
for comb in list(product(colors, colors, colors, colors)):
    counter[tuple(comb)] += 1

print(counter)
print(len(counter))
# Out:
# Counter({('a', 'a', 'a', 'a'): 1, ('a', 'a', 'a', 'b'): 1, ('a', 'a', 'a', 'c'): 1, ('a', 'a', 'a', 'd'): 1, ('a', 'a', 'a', 'e'): 1, ('a', 'a', 'a', 'f'): 1, ('a', 'a', 'b', 'a'): 1, ('a', 'a', 'b', 'b'): 1, ('a', 'a', 'b', 'c'): 1, ('a', 'a', 'b', 'd'): 1, ('a', 'a', 'b', 'e'): 1, ('a', 'a', 'b', 'f'): 1, ('a', 'a', 'c', 'a'): 1, ('a', 'a', 'c', 'b'): 1, ('a', 'a', 'c', 'c'): 1, ('a', 'a', 'c', 'd'): 1, ('a', 'a', 'c', 'e'): 1, ('a', 'a', 'c', 'f'): 1, ('a', 'a', 'd', 'a'): 1, ('a', 'a', 'd', 'b'): 1, ('a', 'a', 'd', 'c'): 1, ('a', 'a', 'd', 'd'): 1, ('a', 'a', 'd', 'e'): 1, ('a', 'a', 'd', 'f'): 1, ('a', 'a', 'e', 'a'): 1, ('a', 'a', 'e', 'b'): 1, ('a', 'a', 'e', 'c'): 1, ('a', 'a', 'e', 'd'): 1, ('a', 'a', 'e', 'e'): 1, ('a', 'a', 'e', 'f'): 1, ('a', 'a', 'f', 'a'): 1, ('a', 'a', 'f', 'b'): 1, ('a', 'a', 'f', 'c'): 1, ('a', 'a', 'f', 'd'): 1, ('a', 'a', 'f', 'e'): 1, ('a', 'a', 'f', 'f'): 1, ('a', 'b', 'a', 'a'): 1, ('a', 'b', 'a', 'b'): 1, ('a', 'b', 'a', 'c'): 1, ('a', 'b', 'a'
# ...
